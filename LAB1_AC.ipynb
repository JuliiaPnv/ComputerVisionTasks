# %% [markdown]
# <a href="https://colab.research.google.com/github/JuliiaPnv/ComputerVisionTasks/blob/main/LAB1_AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-181687d0-6fcf-4cdb-84a4-045cfb736d5e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-181687d0-6fcf-4cdb-84a4-045cfb736d5e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

# Получение текущей рабочей директории
current_directory = os.getcwd()
print("Текущая директория:", current_directory)
# Out:
# Текущая директория: /content

# %%
# !pip uninstall -y spacy torch
# !pip install spacy torch
# !python -m spacy download ru_core_news_sm
# !pip install docx2txt
import spacy
# Out:
# Found existing installation: spacy 3.7.5
# Uninstalling spacy-3.7.5:
#   Successfully uninstalled spacy-3.7.5
# Found existing installation: torch 2.6.0+cu124
# Uninstalling torch-2.6.0+cu124:
#   Successfully uninstalled torch-2.6.0+cu124
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.6/30.6 MB 58.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.7/766.7 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 90.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 58.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 30.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.3 MB/s eta 0:00:00
# ...

# %%
# Установка djvulibre
# !apt-get update
# !apt-get install -y djvulibre-bin
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:8 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [3,798 kB]
# Get:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,692 kB]
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,753 kB]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# ...

# %%
# !pip install langdetect

# Разработка синтаксического анализатора  для обработки HTML страниц

# !pip install beautifulsoup4
from bs4 import BeautifulSoup
import requests
url = 'https://74.ru/' # url страницы
response = requests.get(url)
# Проверка успешности запроса
if response.status_code == 200:
    # Сохранение HTML-кода страницы в переменной
    html_content = response.text
    print(html_content)  # Вывод HTML-кода
else:
    print(f"Ошибка при загрузке страницы: {response.status_code}")
response.encoding = 'utf-8'
html_content = response.text
# Парсинг HTML с помощью BeautifulSoup
soup = BeautifulSoup(html_content, 'html.parser')

# Пример: извлечение текста из всех параграфов
paragraphs = soup.find_all('p')
for paragraph in paragraphs:
    print(paragraph.text.strip())

# Разработка синтаксического анализатора для автоматизированной обработки документов
# форматов .pdf, .doc, .docx, djvu

# Библиотеки yMuPDF или PyPDF2 для PDF.
# python-docx для DOCX.
# pywin32 или docx2txt для DOC.
# python-djvulibre для DJVU.

# !pip install pymupdf
# !pip install python-docx

import fitz  # PyMuPDF
import spacy
from langdetect import detect


# Функция для извлечения текста из PDF
#def extract_text_from_pdf("/content/19 определение свалок пекин 1.pdf"):
#    doc = fitz.open('/content/19 определение свалок пекин 1.pdf')
#    text = ""
#    for page_num in range(len(doc)):
#        page = doc.load_page(page_num)
#        text += page.get_text()
 #   return text
#file_path = "/content/19 определение свалок пекин 1.pdf"
#pdf_text = extract_text_from_pdf(file_path)
#print(pdf_text)


import fitz  # PyMuPDF

def extract_text_from_pdf(file_path):
    # Открываем PDF-документ
    document = fitz.open(file_path)
    text = ""

    # Перебираем страницы и извлекаем текст
    for page_num in range(len(document)):
        page = document.load_page(page_num)
        text += page.get_text()

    return text

# Пример использования функции
file_path = "/content/19 определение свалок пекин 1.pdf"
pdf_text = extract_text_from_pdf(file_path)
print(pdf_text)

# Функция для синтаксического анализа текста
def analyze_text(pdf_text):
    # Определение языка текста
    language = detect(pdf_text)

    # Загрузка соответствующей модели spaCy
    if language == 'en':
        nlp = spacy.load("en_core_web_sm")
    elif language == 'ru':
        nlp = spacy.load("ru_core_news_sm")
    else:
        raise ValueError(f"Модель для языка {language} не найдена.")

    # Анализ текста
    doc = nlp(pdf_text)
    for token in doc:
        print(token.text, token.lemma_, token.pos_, token.dep_)

# Пример использования
pdf_text = extract_text_from_pdf('/content/19 определение свалок пекин 1.pdf')
analyze_text(pdf_text)

# Извлечение текста DOCX
from docx import Document

def extract_text_from_docx(file_path):
    doc = Document(file_path)
    full_text = []
    for para in doc.paragraphs:
        full_text.append(para.text)
    return '\n'.join(full_text)

# Пример использования
docx_text = extract_text_from_docx('/content/069949_С01-02 Учебная практика (научно-исследовательская работа) (2).docx')
print(docx_text)

from docx import Document

# Загрузка модели для русского языка
nlp = spacy.load("ru_core_news_sm")

def extract_text_from_docx(file_path):
    doc = Document(file_path)
    full_text = []
    for para in doc.paragraphs:
        full_text.append(para.text)
    return '\n'.join(full_text)

def analyze_syntax(text):
    # Обработка текста с помощью spaCy
    doc = nlp(text)

    # Вывод токенов и их синтаксических зависимостей
    for token in doc:
        print(f"Token: {token.text}, Lemma: {token.lemma_}, POS: {token.pos_}, Dependency: {token.dep_}, Head: {token.head.text}")

# Пример использования
file_path = '/content/069949_С01-02 Учебная практика (научно-исследовательская работа) (2).docx'
docx_text = extract_text_from_docx(file_path)
print("Извлеченный текст:")
print(docx_text)

print("\nСинтаксический анализ:")
analyze_syntax(docx_text)


import docx2txt
import spacy
from langdetect import detect
from docx import Document

# Установка необходимых библиотек
# !apt-get install antiword
# !pip install spacy langdetect

# Установка моделей spaCy
# !python -m spacy download en_core_web_sm
# !python -m spacy download ru_core_news_sm

import subprocess

from langdetect import detect

# Функция для извлечения текста из DOC
def extract_text_from_doc(file_path):
    result = subprocess.run(['antiword', file_path], stdout=subprocess.PIPE)
    return result.stdout.decode('utf-8')

# Функция для синтаксического анализа текста
def analyze_text(text):
    # Определение языка текста
    language = detect(text)

    # Загрузка соответствующей модели spaCy
    if language == 'en':
        nlp = spacy.load("en_core_web_sm")
    elif language == 'ru':
        nlp = spacy.load("ru_core_news_sm")
    else:
        raise ValueError(f"Модель для языка {language} не найдена.")

    # Анализ текста
    doc = nlp(text)
    for token in doc:
        print(token.text, token.lemma_, token.pos_, token.dep_)

# Пример использования
doc_path = '/content/Ценность и Целостность Личности Курс.doc'  # Убедитесь, что путь указан правильно
doc_text = extract_text_from_doc(doc_path)
analyze_text(doc_text)


import subprocess

def extract_text_from_djvu(file_path):
    # Выполнение команды djvutxt для извлечения текста
    result = subprocess.run(['djvutxt', file_path, 'output.txt'], stdout=subprocess.PIPE)
    # Чтение текста из файла
    with open('output.txt', 'r') as file:
        text = file.read()
    return text

# Пример использования
file_path = '/content/_Эльконин Д.Б., Психическое развитие в детских возрастах.djvu'  # Замените на ваш путь к файлу
djvu_text = extract_text_from_djvu(file_path)
print(djvu_text)

# Загрузка модели для русского языка
nlp = spacy.load("ru_core_news_sm")

def extract_text_from_djvu(file_path):
    # Выполнение команды djvutxt для извлечения текста
    result = subprocess.run(['djvutxt', file_path, 'output.txt'], stdout=subprocess.PIPE)
    # Чтение текста из файла
    with open('output.txt', 'r') as file:
        text = file.read()
    return text

def analyze_syntax(text):
    # Обработка текста с помощью spaCy
    doc = nlp(text)

    # Вывод токенов и их синтаксических зависимостей
    for token in doc:
        print(f"Token: {token.text}, Lemma: {token.lemma_}, POS: {token.pos_}, Dependency: {token.dep_}, Head: {token.head.text}")

# Пример использования
file_path = '/content/_Эльконин Д.Б., Психическое развитие в детских возрастах.djvu'  # Замените на ваш путь к файлу
djvu_text = extract_text_from_djvu(file_path)
print("Извлеченный текст:")
print(djvu_text)

print("\nСинтаксический анализ:")
analyze_syntax(djvu_text)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 12.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993222 sha256=eabaafea5417983b3389bee326faf705cf577b600de53d0a7eb9ff85f21ef4e5
#   Stored in directory: /root/.cache/pip/wheels/0a/f2/b2/e5ca405801e05eb7c8ed5b3b4bcf1fcabcd6272c167640072e
# Successfully built langdetect
# ...
# <!DOCTYPE html>
# <html lang="ru">
#   <head>
#     <meta charset="UTF-8" />
#     <meta name="viewport" content="width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=1,user-scalable=yes">
#     <meta name="referrer" content="no-referrer-when-downgrade" />
#     <title>ÐÐ¾Ð²Ð¾ÑÑÐ¸ Ð§ÐµÐ»ÑÐ±Ð¸Ð½ÑÐºÐ° Ð¸ Ð§ÐµÐ»ÑÐ±Ð¸Ð½ÑÐºÐ¾Ð¹ Ð¾Ð±Ð»Ð°ÑÑÐ¸ | 74.ÑÑ</title>
#
#     <style>.blockSection_e6cTn{display:flex;gap:12px}.blockSectionHorizontal_e6cTn{flex-flow:column}
# ...

# %%
# !ls /content
# Out:
# '19 определение свалок пекин 1 (1).pdf'  '19 определение свалок пекин 1.pdf'
# '19 определение свалок пекин 1 (2).pdf'   sample_data

# %%
from google.colab import drive
drive.mount('/content/drive')
